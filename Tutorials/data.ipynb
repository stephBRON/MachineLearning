# %% [markdown]
# # Notebook to download useful data

# %%
import kagglehub

# %%
# Download latest version
path = kagglehub.dataset_download("jamiewelsh2/nba-player-salaries-2022-23-season")
print("Path to dataset files:", path)

# Download latest version
path = kagglehub.dataset_download("harrywang/housing")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/sbron/.cache/kagglehub/datasets/jamiewelsh2/nba-player-salaries-2022-23-season/2.archive...
# 100%|██████████| 72.6k/72.6k [00:00<00:00, 6.82MB/s]
# Extracting files...
# Path to dataset files: /home/sbron/.cache/kagglehub/datasets/jamiewelsh2/nba-player-salaries-2022-23-season/versions/2
# Downloading to /home/sbron/.cache/kagglehub/datasets/harrywang/housing/4.archive...
# 100%|██████████| 400k/400k [00:00<00:00, 13.6MB/s]
# Extracting files...
# Path to dataset files: /home/sbron/.cache/kagglehub/datasets/harrywang/housing/versions/4

# %%
# TODO: mv folder to ../Data/kagglehub/
